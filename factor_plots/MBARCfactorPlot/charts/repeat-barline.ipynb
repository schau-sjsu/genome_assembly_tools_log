# %%
import pandas as pd

data = pd.read_csv("/scratch/rnd-rojas/assembly_stephanie/data/repeat.csv")
data
# Out:
#                           Species  Whole Genome    16S
# 0         Clostridium_perfringens          0.01  39.67
# 1        Clostridium_thermocellum          0.01  28.57
# 2    Coraliomargarita_akajimensis          0.00  36.75
# 3      Corynebacterium_glutamicum          0.01  37.01
# 4   Desulfosporosinus_acidiphilus          0.00  22.07
# 5      Desulfosporosinus_meridiei          0.00  29.39
# 6      Desulfotomaculum_gibsoniae          0.00  29.19
# 7                          E.coli          0.01  39.34
# 8         Echinicola_vietnamensis          0.00  36.21
# 9    Fervidobacterium_pennivorans          0.00  17.53
# 10             Frateuria_aurantia          0.01  42.18
# 11                Halovivax_ruber          0.00  38.88
# 12               Hirschia_baltica          0.00  35.89
# 13           Meiothermus_silvanus          0.00  21.21
# 14      Natronobacterium_gregoryi          0.00  40.98
# 15         Natronococcus_occultus          0.00  38.21
# 16      Nocardiopsis_dassonvillei          0.01  28.96
# 17                  Olsenella_uli          0.02  42.69
# 18           Pseudomonas_stutzeri          0.00  40.53
# 19             Salmonella_bongori          0.01  39.34
# 20            Salmonella_enterica          0.01  39.34
# 21          Segniliparus_rotundus          0.00  37.74
# 22        Spirochaeta_smaragdinae          0.00  36.15
# 23         Streptococcus_pyogenes          0.00  36.11
# 24             Terriglobus_roseus          0.00  40.05
# 25        Thermobacillus_composti          0.00  27.39

# %%
import pandas as pd
import altair as alt

data = pd.read_csv("/scratch/rnd-rojas/assembly_stephanie/data/repeat.csv")
df = pd.DataFrame(data, columns=['Species', 'Whole Genome', '16S'])

colors=['thistle', 'thistle', 'thistle', 'thistle', 'thistle', 'thistle', 'thistle', 'lightsteelblue', 'thistle', 
        '#ffbe33', 'thistle', 'thistle', 'thistle', 'thistle', 'thistle', 'thistle', 'palevioletred', 
        'thistle', 'thistle', '#549a8b', 'thistle', 'thistle', 'thistle', 'thistle', 'thistle', 'thistle']

base = alt.Chart(df, title='Repetitiveness (%)').encode(
    x=alt.X('Species:N',
           sort=alt.SortField(field='16S', order='descending')
           )
)

bar = base.mark_bar(size=25).encode(
    y=alt.Y(
            '16S:Q',
            title='16S'
           ),
        color=alt.Color(
           'Species',
            scale=alt.Scale(
                domain=df.Species.tolist(),
                range=colors
            ),
            legend=None
           )
    ).properties(width=1500, height=450)

line = base.mark_line(color='black', opacity=0.4).encode(
    y=alt.Y(
            'Whole Genome:Q'
           )
    )

textbar = bar.mark_text(
    align='center',
    baseline='middle',
    dy=-35,
    fontWeight='bold',
    fontSize=12
).encode(
    text='16S:Q',
    y=alt.value(45)
)

textline = line.mark_text(
    align='center',
    baseline='middle',
    dy=-10,
    fontWeight='bold',
    fontSize=12,
    opacity=0.8,
    color='black'
).encode(
    text=alt.Text(
        'Whole Genome:Q',
        format=",.2f"
    )
)

bardata = pd.DataFrame({'x':['Whole Genome'], 'y':['16S']})

legendbar = alt.Chart(bardata).mark_square(size=200, color='thistle').encode(
    y=alt.Y('y:N', 
            axis=alt.Axis(orient='right', 
                          titleFontSize=0, 
                          labelFontSize=16, 
                          titleX=80, 
                          titleY=-5,
                          titleAngle=0
                         ),
    
           ),
    )

legendline = alt.Chart(bardata).mark_tick(
        size=15, 
        thickness=3, 
        orient='horizontal', 
        color='black',
        opacity=0.4
).encode(
            y=alt.Y('x:N', 
                    axis=alt.Axis(orient='right', 
                                  titleFontSize=0, 
                                  labelFontSize=16, 
                                  titleX=80, 
                                  titleY=-5,
                                  titleAngle=0
                                 ),

                   ),
    )

(bar + textbar + line + textline | legendbar + legendline).configure_axisX(
    labelAngle=-45,
    labelPadding=10,
    labelLimit=1000,
    titleFontSize=14,
    labelFontSize=12,
    titleY=200
).configure_title(
    fontSize=18
).configure_axisY(
    titleFontSize=14,
    labelPadding=10,
    titleX=-60
)
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## References
#
# * https://altair-viz.github.io/gallery/bar_and_line_with_dual_axis.html
