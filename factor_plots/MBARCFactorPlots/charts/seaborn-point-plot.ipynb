# %%
import seaborn as sea
import pandas as pd

# %%
cov = pd.read_csv('/scratch/rnd-rojas/assembly_stephanie/data/bincov-data.csv')
sea.pointplot(x="Running Position", y="Clostridium_perfringensATCC_13124 ", data=cov)
# Out:
# <AxesSubplot:xlabel='Running Position', ylabel='Clostridium_perfringensATCC_13124 '>
